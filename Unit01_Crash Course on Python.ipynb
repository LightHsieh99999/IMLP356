# %% [markdown]
# # Python programming
# ## Crash Course on Python Coding Practice
#
# No matter the level of mastery you hope to get to in Python,<br>
# you'll need these fundamentals in place before you jump into any project.<br><br>
#
# You need to know how to:
#
# - declare variables
# - collect user input
# - store information
# - repeat an action through loops
# - write functions to repeat blocks of code

# %%
### 01 - 奇偶數辨別（Odd or even）
#### 當使用者輸入一個的數字，它能夠辨別奇偶，並輸出檢驗結果給使用者。

> 題目：輸入一數字判斷奇數或偶數<br>
輸入(Input): 一個數字 <br>
輸出(Output):奇數或偶數

* 進階: 可以限制輸入一個介於一定範圍（例如 1 到 1000）的數字

# %%
while True:
    x=input("請輸入數字介於1至1000:")
    y=int(x)
    if 1<=y and y<=1000:
        if y%2==0:
            print("你輸入的是偶數")  
        else:
            print("你輸入的是奇數")
        break
    else:
        print("你輸入的不在1到1000的範圍內")
# Out:
# 請輸入數字介於1至1000:10000
# 你輸入的不在1到1000的範圍內
# 請輸入數字介於1至1000:1003
# 你輸入的不在1到1000的範圍內
# 請輸入數字介於1至1000:1001
# 你輸入的不在1到1000的範圍內
# 請輸入數字介於1至1000:1000
# 你輸入的是偶數

# %%
### 02 - 填字遊戲（Mad libs game）
#### 使用者輸入任何字，它可以是名詞、形容詞、動詞、代名詞等。程式得到文字後，可自行排列，組成成一個模板故事。

> 題目：輸入一數字判斷奇數或偶數<br>
輸入(Input): 一連串依據說明輸入對應文字 <br>
輸出(Output): 模板故事

* 進階: 可以讓程式重複執行
# Out:
#   File "<ipython-input-2-cf133318c68b>", line 4
#     > 題目：輸入一數字判斷奇數或偶數<br>
#     ^
# SyntaxError: invalid syntax

# %%
import random
#請輸入你想要完成的次數
aa=input("請輸入你想要完成的次數:")
num=int(aa)
for i in range(0,num):
    x=random.randint(1,10)
    name=input("請輸入你的姓名:")
    birthday=input("請輸入你的生日:西元/月份/日期 ex:1988/07/11:")
    address=input("請輸入你的地址:")
    ID=input("請輸入你的身份證字號:")
    print("--------------------------------------------------------")
    print("恭喜你",name,"先生/小姐")
    print("你中了統一發票",x*100,"萬元")
    print("以下請確認你的個人資料，如沒有錯誤，將在10天內將獎金匯入你銀行帳戶")
    print("--------------------------------------------------------")
    print("姓名:",name,"先生/小姐")
    print("身份證字號:",ID,)
    print("生日:",birthday,)
    print("居住地址:",address,)
# Out:
# 請輸入你想要完成的次數:2
# 請輸入你的姓名:謝小智
# 請輸入你的生日:西元/月份/日期 ex:1988/07/11:1999/3/4
# 請輸入你的地址:信義區
# 請輸入你的身份證字號:A123456789
# --------------------------------------------------------
# 恭喜你 謝小智 先生/小姐
# 你中了統一發票 300 萬元
# 以下請確認你的個人資料，如沒有錯誤，將在10天內將獎金匯入你銀行帳戶
# --------------------------------------------------------
# 姓名: 謝小智 先生/小姐
# 身份證字號: A123456789
# 生日: 1999/3/4
# 居住地址: 信義區
# 請輸入你的姓名:謝大智
# 請輸入你的生日:西元/月份/日期 ex:1988/07/11:1988/7/9
# 請輸入你的地址:中山區
# 請輸入你的身份證字號:G1111111233
# --------------------------------------------------------
# 恭喜你 謝大智 先生/小姐
# 你中了統一發票 700 萬元
# 以下請確認你的個人資料，如沒有錯誤，將在10天內將獎金匯入你銀行帳戶
# --------------------------------------------------------
# 姓名: 謝大智 先生/小姐
# 身份證字號: G1111111233
# 生日: 1988/7/9
# 居住地址: 中山區

# %% [markdown]
# ### 03 -  猜數字（Guess the number）
# #### 請使用者猜一個介於範圍（例如 1 到 100）之間的數字，
# #### 若使用者猜錯，就詢問他們想繼續玩還是退出；若使用者猜對，就顯示祝賀訊息，
# #### 並統計使用者的嘗試次數。如果使用者輸入的數字超出設定範圍，就顯示錯誤提示。
#
# ![](data\guess.png)

# %%
import random 
num=random.randint(1,100)
count=1
repeat='Y'
ans='Y'
while True:
    if repeat==ans:
        print("這是第",count,"次猜測")
        print("請輸入1到100的數字")
        x=input()
        y=int(x)
        if y>100 or y<0:
             print("輸入的數字不在範圍內，請重新輸入數字1到100之間的數字")

        else:
            if y==num:
                print("恭喜你，猜對數字了")
                break
            elif y>num:
                print("你輸入的數字太大了，請重新輸入較小的數字")
            else:
                print("你輸入的數字太小了，請重新輸入較大的數字")
        print("是否要繼續玩下去(Y/N):")
        repeat=input()       
        count+=1
    else:
        break
# Out:
# 這是第 1 次猜測
# 請輸入1到100的數字
# 3
# 你輸入的數字太小了，請重新輸入較大的數字
# 是否要繼續玩下去(Y/N):
# Y
# 這是第 2 次猜測
# 請輸入1到100的數字
# 50
# 你輸入的數字太大了，請重新輸入較小的數字
# 是否要繼續玩下去(Y/N):
# Y
# 這是第 3 次猜測
# 請輸入1到100的數字
# 40
# 你輸入的數字太大了，請重新輸入較小的數字
# 是否要繼續玩下去(Y/N):
# Y
# 這是第 4 次猜測
# 請輸入1到100的數字
# 25
# 你輸入的數字太小了，請重新輸入較大的數字
# 是否要繼續玩下去(Y/N):
# Y
# 這是第 5 次猜測
# 請輸入1到100的數字
# 30
# 你輸入的數字太小了，請重新輸入較大的數字
# 是否要繼續玩下去(Y/N):
# Y
# 這是第 6 次猜測
# 請輸入1到100的數字
# 35
# 你輸入的數字太小了，請重新輸入較大的數字
# 是否要繼續玩下去(Y/N):
# Y
# 這是第 7 次猜測
# 請輸入1到100的數字
# 38
# 你輸入的數字太大了，請重新輸入較小的數字
# 是否要繼續玩下去(Y/N):
# Y
# 這是第 8 次猜測
# 請輸入1到100的數字
# 37
# 你輸入的數字太大了，請重新輸入較小的數字
# 是否要繼續玩下去(Y/N):
# Y
# 這是第 9 次猜測
# 請輸入1到100的數字
# 36
# 恭喜你，猜對數字了

# %% [markdown]
# ### 04 - 計算字數（Word count）
# #### 使用者輸入一段文字或讀取一檔案，程式統計字數。
#
# > 輸入(Input):我要成為寫程式的專家 <br>
# 輸出(Output):你用了 10 個文字述說內心的想法
#
# #### 在特定的文章字串中搜尋輸入的特定字，請使用者輸入欲搜尋的文字，印出總共有幾個。<br>
# >輸入(Input):天<br>
# 輸出(Output): 9
#
# * 進階:計算文章中去除標點符號後的字數，找出文章中出現最多的字與次數

# %%
word = input()
print("你用了 %d 個文字述說內心的想法"%(len(word)))


s = '''漢皇重色思傾國，御宇多年求不得。

楊家有女初長成，養在深閏人未識。

天生麗質難自棄，一朝選在君王側。

回眸一笑百媚生，六宮粉黛無顏色。

春寒賜浴華清池，溫泉水滑洗凝脂；

侍兒扶起嬌無力，始是新承恩澤時。

雲鬢花顏金步搖，芙蓉帳暖度春宵；

春宵苦短日高起，從此君王不早朝。

承歡侍宴無閑暇，春從春遊夜專夜。

後宮佳麗三千人，三千寵愛在一身。

金屋妝成嬌侍夜，玉樓宴罷醉和春。

姊妹弟兄皆列士，可憐光彩生門戶。

遂令天下父母心，不重生男重生女。

驪宮高處入青雲，仙樂風飄處處聞。

緩歌慢舞凝絲竹，盡日君王看不足。

漁陽鼙鼓動地來，驚破霓裳羽衣曲。

九重城闕煙塵生，千乘萬騎西南行。

翠華搖搖行復止，西出都門百餘里；

六軍不發無奈何？宛轉蛾眉馬前死。

花鈿委地無人收，翠翹金雀玉搔頭。

君王掩面救不得，回看血淚相和流。

黃埃散漫風蕭索，雲棧縈紆登劍閣。

峨嵋山下少人行，旌旗無光日色薄。

蜀江水碧蜀山青，聖主朝朝暮暮情。

行宮見月傷心色，夜雨聞鈴腸斷聲。

天旋地轉迴龍馭，到此躊躇不能去。

馬嵬坡下泥土中，不見玉顏空死處。

君臣相顧盡霑衣，東望都門信馬歸。

歸來池苑皆依舊，太液芙蓉未央柳；

芙蓉如面柳如眉，對此如何不淚垂？

春風桃李花開日，秋雨梧桐葉落時。

西宮南內多秋草，落葉滿階紅不掃。

梨園子弟白髮新，椒房阿監青娥老。

夕殿螢飛思悄然，孤燈挑盡未成眠。

遲遲鐘鼓初長夜，耿耿星河欲曙天。

鴛鴦瓦冷霜華重，翡翠衾寒誰與共？

悠悠生死別經年，魂魄不曾來入夢。

臨邛道士鴻都客，能以精誠致魂魄；

為感君王輾轉思，遂教方士殷勤覓。

排空馭氣奔如電，升天入地求之遍；

上窮碧落下黃泉，兩處茫茫皆不見。

忽聞海上有仙山，山在虛無縹緲間。

樓閣玲瓏五雲起，其中綽約多仙子。

中有一人字太真，雪膚花貌參差是。

金闕西廂叩玉扃，轉教小玉報雙成。

聞道漢家天子使，九華帳裡夢魂驚；

攬衣推枕起徘徊，珠箔銀屏迤邐開。

雲鬢半偏新睡覺，花冠不整下堂來。

風吹仙袂飄飄舉，猶似霓裳羽衣舞。

玉容寂寞淚闌干，梨花一枝春帶雨。

含情凝睇謝君王，一別音容兩渺茫。

昭陽殿裡恩愛絕，蓬萊宮中日月長。

回頭下望人寰處，不見長安見塵霧。

唯將舊物表深情，鈿合金釵寄將去。

釵留一股合一扇，釵擘黃金合分鈿。

但教心似金鈿堅，天上人間會相見。

臨別殷勤重寄詞，詞中有誓兩心知，

七月七日長生殿，夜半無人私語時：「

在天願作比翼鳥，在地願為連理枝。」

天長地久有時盡，此恨綿綿無絕期。
'''

print ("------------------------------------------")

word2=input()
s_number=s.count(word2)
print("你想要找尋的字%s,共有%s個字:"%(word2,s_number))

print ("------------------------------------------")
#把文字中 '。，\n；：？「」'的標點符號去除

for i in '。，\n；：？「」':
    s=s.replace(i,'')
 
print('文章總字數:',len(s))
maxchar=0
maxchar_name='none'
for astr in s:
    act=s.count(astr)
    print("現在出現的文字{%s},共有%d個:"%(astr,act))
    if act>maxchar:
        maxchar=act  
        maxchar_name=astr
    
print("出現最多次數的文字是 {%s},總共有%d個:"%(maxchar_name,maxchar))
# Out:
# 我愛你 你說好不好
# 你用了 9 個文字述說內心的想法
# ------------------------------------------
# 不
# 你想要找尋的字不,共有14個字:
# ------------------------------------------
# 文章總字數: 840
# 現在出現的文字{漢},共有2個:
# 現在出現的文字{皇},共有1個:
# 現在出現的文字{重},共有6個:
# 現在出現的文字{色},共有4個:
# 現在出現的文字{思},共有3個:
# 現在出現的文字{傾},共有1個:
# 現在出現的文字{國},共有1個:
# 現在出現的文字{御},共有1個:
# 現在出現的文字{宇},共有1個:
# 現在出現的文字{多},共有3個:
# 現在出現的文字{年},共有2個:
# 現在出現的文字{求},共有2個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{得},共有2個:
# 現在出現的文字{楊},共有1個:
# 現在出現的文字{家},共有2個:
# 現在出現的文字{有},共有5個:
# 現在出現的文字{女},共有2個:
# 現在出現的文字{初},共有2個:
# 現在出現的文字{長},共有6個:
# 現在出現的文字{成},共有4個:
# 現在出現的文字{養},共有1個:
# 現在出現的文字{在},共有6個:
# 現在出現的文字{深},共有2個:
# 現在出現的文字{閏},共有1個:
# 現在出現的文字{人},共有8個:
# 現在出現的文字{未},共有3個:
# 現在出現的文字{識},共有1個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{生},共有8個:
# 現在出現的文字{麗},共有2個:
# 現在出現的文字{質},共有1個:
# 現在出現的文字{難},共有1個:
# 現在出現的文字{自},共有1個:
# 現在出現的文字{棄},共有1個:
# 現在出現的文字{一},共有8個:
# 現在出現的文字{朝},共有4個:
# 現在出現的文字{選},共有1個:
# 現在出現的文字{在},共有6個:
# 現在出現的文字{君},共有7個:
# 現在出現的文字{王},共有6個:
# 現在出現的文字{側},共有1個:
# 現在出現的文字{回},共有3個:
# 現在出現的文字{眸},共有1個:
# 現在出現的文字{一},共有8個:
# 現在出現的文字{笑},共有1個:
# 現在出現的文字{百},共有2個:
# 現在出現的文字{媚},共有1個:
# 現在出現的文字{生},共有8個:
# 現在出現的文字{六},共有2個:
# 現在出現的文字{宮},共有6個:
# 現在出現的文字{粉},共有1個:
# 現在出現的文字{黛},共有1個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{顏},共有3個:
# 現在出現的文字{色},共有4個:
# 現在出現的文字{春},共有8個:
# 現在出現的文字{寒},共有2個:
# 現在出現的文字{賜},共有1個:
# 現在出現的文字{浴},共有1個:
# 現在出現的文字{華},共有4個:
# 現在出現的文字{清},共有1個:
# 現在出現的文字{池},共有2個:
# 現在出現的文字{溫},共有1個:
# 現在出現的文字{泉},共有2個:
# 現在出現的文字{水},共有2個:
# 現在出現的文字{滑},共有1個:
# 現在出現的文字{洗},共有1個:
# 現在出現的文字{凝},共有3個:
# 現在出現的文字{脂},共有1個:
# 現在出現的文字{侍},共有3個:
# 現在出現的文字{兒},共有1個:
# 現在出現的文字{扶},共有1個:
# 現在出現的文字{起},共有4個:
# 現在出現的文字{嬌},共有2個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{力},共有1個:
# 現在出現的文字{始},共有1個:
# 現在出現的文字{是},共有2個:
# 現在出現的文字{新},共有3個:
# 現在出現的文字{承},共有2個:
# 現在出現的文字{恩},共有2個:
# 現在出現的文字{澤},共有1個:
# 現在出現的文字{時},共有4個:
# 現在出現的文字{雲},共有5個:
# 現在出現的文字{鬢},共有2個:
# 現在出現的文字{花},共有6個:
# 現在出現的文字{顏},共有3個:
# 現在出現的文字{金},共有7個:
# 現在出現的文字{步},共有1個:
# 現在出現的文字{搖},共有3個:
# 現在出現的文字{芙},共有3個:
# 現在出現的文字{蓉},共有3個:
# 現在出現的文字{帳},共有2個:
# 現在出現的文字{暖},共有1個:
# 現在出現的文字{度},共有1個:
# 現在出現的文字{春},共有8個:
# 現在出現的文字{宵},共有2個:
# 現在出現的文字{春},共有8個:
# 現在出現的文字{宵},共有2個:
# 現在出現的文字{苦},共有1個:
# 現在出現的文字{短},共有1個:
# 現在出現的文字{日},共有6個:
# 現在出現的文字{高},共有2個:
# 現在出現的文字{起},共有4個:
# 現在出現的文字{從},共有2個:
# 現在出現的文字{此},共有4個:
# 現在出現的文字{君},共有7個:
# 現在出現的文字{王},共有6個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{早},共有1個:
# 現在出現的文字{朝},共有4個:
# 現在出現的文字{承},共有2個:
# 現在出現的文字{歡},共有1個:
# 現在出現的文字{侍},共有3個:
# 現在出現的文字{宴},共有2個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{閑},共有1個:
# 現在出現的文字{暇},共有1個:
# 現在出現的文字{春},共有8個:
# 現在出現的文字{從},共有2個:
# 現在出現的文字{春},共有8個:
# 現在出現的文字{遊},共有1個:
# 現在出現的文字{夜},共有6個:
# 現在出現的文字{專},共有1個:
# 現在出現的文字{夜},共有6個:
# 現在出現的文字{後},共有1個:
# 現在出現的文字{宮},共有6個:
# 現在出現的文字{佳},共有1個:
# 現在出現的文字{麗},共有2個:
# 現在出現的文字{三},共有2個:
# 現在出現的文字{千},共有3個:
# 現在出現的文字{人},共有8個:
# 現在出現的文字{三},共有2個:
# 現在出現的文字{千},共有3個:
# 現在出現的文字{寵},共有1個:
# 現在出現的文字{愛},共有2個:
# 現在出現的文字{在},共有6個:
# 現在出現的文字{一},共有8個:
# 現在出現的文字{身},共有1個:
# 現在出現的文字{金},共有7個:
# 現在出現的文字{屋},共有1個:
# 現在出現的文字{妝},共有1個:
# 現在出現的文字{成},共有4個:
# 現在出現的文字{嬌},共有2個:
# 現在出現的文字{侍},共有3個:
# 現在出現的文字{夜},共有6個:
# 現在出現的文字{玉},共有6個:
# 現在出現的文字{樓},共有2個:
# 現在出現的文字{宴},共有2個:
# 現在出現的文字{罷},共有1個:
# 現在出現的文字{醉},共有1個:
# 現在出現的文字{和},共有2個:
# 現在出現的文字{春},共有8個:
# 現在出現的文字{姊},共有1個:
# 現在出現的文字{妹},共有1個:
# 現在出現的文字{弟},共有2個:
# 現在出現的文字{兄},共有1個:
# 現在出現的文字{皆},共有3個:
# 現在出現的文字{列},共有1個:
# 現在出現的文字{士},共有3個:
# 現在出現的文字{可},共有1個:
# 現在出現的文字{憐},共有1個:
# 現在出現的文字{光},共有2個:
# 現在出現的文字{彩},共有1個:
# 現在出現的文字{生},共有8個:
# 現在出現的文字{門},共有3個:
# 現在出現的文字{戶},共有1個:
# 現在出現的文字{遂},共有2個:
# 現在出現的文字{令},共有1個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{下},共有6個:
# 現在出現的文字{父},共有1個:
# 現在出現的文字{母},共有1個:
# 現在出現的文字{心},共有4個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{重},共有6個:
# 現在出現的文字{生},共有8個:
# 現在出現的文字{男},共有1個:
# 現在出現的文字{重},共有6個:
# 現在出現的文字{生},共有8個:
# 現在出現的文字{女},共有2個:
# 現在出現的文字{驪},共有1個:
# 現在出現的文字{宮},共有6個:
# 現在出現的文字{高},共有2個:
# 現在出現的文字{處},共有6個:
# 現在出現的文字{入},共有3個:
# 現在出現的文字{青},共有3個:
# 現在出現的文字{雲},共有5個:
# 現在出現的文字{仙},共有4個:
# 現在出現的文字{樂},共有1個:
# 現在出現的文字{風},共有4個:
# 現在出現的文字{飄},共有3個:
# 現在出現的文字{處},共有6個:
# 現在出現的文字{處},共有6個:
# 現在出現的文字{聞},共有4個:
# 現在出現的文字{緩},共有1個:
# 現在出現的文字{歌},共有1個:
# 現在出現的文字{慢},共有1個:
# 現在出現的文字{舞},共有2個:
# 現在出現的文字{凝},共有3個:
# 現在出現的文字{絲},共有1個:
# 現在出現的文字{竹},共有1個:
# 現在出現的文字{盡},共有4個:
# 現在出現的文字{日},共有6個:
# 現在出現的文字{君},共有7個:
# 現在出現的文字{王},共有6個:
# 現在出現的文字{看},共有2個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{足},共有1個:
# 現在出現的文字{漁},共有1個:
# 現在出現的文字{陽},共有2個:
# 現在出現的文字{鼙},共有1個:
# 現在出現的文字{鼓},共有2個:
# 現在出現的文字{動},共有1個:
# 現在出現的文字{地},共有6個:
# 現在出現的文字{來},共有4個:
# 現在出現的文字{驚},共有2個:
# 現在出現的文字{破},共有1個:
# 現在出現的文字{霓},共有2個:
# 現在出現的文字{裳},共有2個:
# 現在出現的文字{羽},共有2個:
# 現在出現的文字{衣},共有4個:
# 現在出現的文字{曲},共有1個:
# 現在出現的文字{九},共有2個:
# 現在出現的文字{重},共有6個:
# 現在出現的文字{城},共有1個:
# 現在出現的文字{闕},共有2個:
# 現在出現的文字{煙},共有1個:
# 現在出現的文字{塵},共有2個:
# 現在出現的文字{生},共有8個:
# 現在出現的文字{千},共有3個:
# 現在出現的文字{乘},共有1個:
# 現在出現的文字{萬},共有1個:
# 現在出現的文字{騎},共有1個:
# 現在出現的文字{西},共有4個:
# 現在出現的文字{南},共有2個:
# 現在出現的文字{行},共有4個:
# 現在出現的文字{翠},共有3個:
# 現在出現的文字{華},共有4個:
# 現在出現的文字{搖},共有3個:
# 現在出現的文字{搖},共有3個:
# 現在出現的文字{行},共有4個:
# 現在出現的文字{復},共有1個:
# 現在出現的文字{止},共有1個:
# 現在出現的文字{西},共有4個:
# 現在出現的文字{出},共有1個:
# 現在出現的文字{都},共有3個:
# 現在出現的文字{門},共有3個:
# 現在出現的文字{百},共有2個:
# 現在出現的文字{餘},共有1個:
# 現在出現的文字{里},共有1個:
# 現在出現的文字{六},共有2個:
# 現在出現的文字{軍},共有1個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{發},共有1個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{奈},共有1個:
# 現在出現的文字{何},共有2個:
# 現在出現的文字{宛},共有1個:
# 現在出現的文字{轉},共有4個:
# 現在出現的文字{蛾},共有1個:
# 現在出現的文字{眉},共有2個:
# 現在出現的文字{馬},共有3個:
# 現在出現的文字{前},共有1個:
# 現在出現的文字{死},共有3個:
# 現在出現的文字{花},共有6個:
# 現在出現的文字{鈿},共有4個:
# 現在出現的文字{委},共有1個:
# 現在出現的文字{地},共有6個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{人},共有8個:
# 現在出現的文字{收},共有1個:
# 現在出現的文字{翠},共有3個:
# 現在出現的文字{翹},共有1個:
# 現在出現的文字{金},共有7個:
# 現在出現的文字{雀},共有1個:
# 現在出現的文字{玉},共有6個:
# 現在出現的文字{搔},共有1個:
# 現在出現的文字{頭},共有2個:
# 現在出現的文字{君},共有7個:
# 現在出現的文字{王},共有6個:
# 現在出現的文字{掩},共有1個:
# 現在出現的文字{面},共有2個:
# 現在出現的文字{救},共有1個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{得},共有2個:
# 現在出現的文字{回},共有3個:
# 現在出現的文字{看},共有2個:
# 現在出現的文字{血},共有1個:
# 現在出現的文字{淚},共有3個:
# 現在出現的文字{相},共有3個:
# 現在出現的文字{和},共有2個:
# 現在出現的文字{流},共有1個:
# 現在出現的文字{黃},共有3個:
# 現在出現的文字{埃},共有1個:
# 現在出現的文字{散},共有1個:
# 現在出現的文字{漫},共有1個:
# 現在出現的文字{風},共有4個:
# 現在出現的文字{蕭},共有1個:
# 現在出現的文字{索},共有1個:
# 現在出現的文字{雲},共有5個:
# 現在出現的文字{棧},共有1個:
# 現在出現的文字{縈},共有1個:
# 現在出現的文字{紆},共有1個:
# 現在出現的文字{登},共有1個:
# 現在出現的文字{劍},共有1個:
# 現在出現的文字{閣},共有2個:
# 現在出現的文字{峨},共有1個:
# 現在出現的文字{嵋},共有1個:
# 現在出現的文字{山},共有4個:
# 現在出現的文字{下},共有6個:
# 現在出現的文字{少},共有1個:
# 現在出現的文字{人},共有8個:
# 現在出現的文字{行},共有4個:
# 現在出現的文字{旌},共有1個:
# 現在出現的文字{旗},共有1個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{光},共有2個:
# 現在出現的文字{日},共有6個:
# 現在出現的文字{色},共有4個:
# 現在出現的文字{薄},共有1個:
# 現在出現的文字{蜀},共有2個:
# 現在出現的文字{江},共有1個:
# 現在出現的文字{水},共有2個:
# 現在出現的文字{碧},共有2個:
# 現在出現的文字{蜀},共有2個:
# 現在出現的文字{山},共有4個:
# 現在出現的文字{青},共有3個:
# 現在出現的文字{聖},共有1個:
# 現在出現的文字{主},共有1個:
# 現在出現的文字{朝},共有4個:
# 現在出現的文字{朝},共有4個:
# 現在出現的文字{暮},共有2個:
# 現在出現的文字{暮},共有2個:
# 現在出現的文字{情},共有3個:
# 現在出現的文字{行},共有4個:
# 現在出現的文字{宮},共有6個:
# 現在出現的文字{見},共有6個:
# 現在出現的文字{月},共有3個:
# 現在出現的文字{傷},共有1個:
# 現在出現的文字{心},共有4個:
# 現在出現的文字{色},共有4個:
# 現在出現的文字{夜},共有6個:
# 現在出現的文字{雨},共有3個:
# 現在出現的文字{聞},共有4個:
# 現在出現的文字{鈴},共有1個:
# 現在出現的文字{腸},共有1個:
# 現在出現的文字{斷},共有1個:
# 現在出現的文字{聲},共有1個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{旋},共有1個:
# 現在出現的文字{地},共有6個:
# 現在出現的文字{轉},共有4個:
# 現在出現的文字{迴},共有1個:
# 現在出現的文字{龍},共有1個:
# 現在出現的文字{馭},共有2個:
# 現在出現的文字{到},共有1個:
# 現在出現的文字{此},共有4個:
# 現在出現的文字{躊},共有1個:
# 現在出現的文字{躇},共有1個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{能},共有2個:
# 現在出現的文字{去},共有2個:
# 現在出現的文字{馬},共有3個:
# 現在出現的文字{嵬},共有1個:
# 現在出現的文字{坡},共有1個:
# 現在出現的文字{下},共有6個:
# 現在出現的文字{泥},共有1個:
# 現在出現的文字{土},共有1個:
# 現在出現的文字{中},共有5個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{見},共有6個:
# 現在出現的文字{玉},共有6個:
# 現在出現的文字{顏},共有3個:
# 現在出現的文字{空},共有2個:
# 現在出現的文字{死},共有3個:
# 現在出現的文字{處},共有6個:
# 現在出現的文字{君},共有7個:
# 現在出現的文字{臣},共有1個:
# 現在出現的文字{相},共有3個:
# 現在出現的文字{顧},共有1個:
# 現在出現的文字{盡},共有4個:
# 現在出現的文字{霑},共有1個:
# 現在出現的文字{衣},共有4個:
# 現在出現的文字{東},共有1個:
# 現在出現的文字{望},共有2個:
# 現在出現的文字{都},共有3個:
# 現在出現的文字{門},共有3個:
# 現在出現的文字{信},共有1個:
# 現在出現的文字{馬},共有3個:
# 現在出現的文字{歸},共有2個:
# 現在出現的文字{歸},共有2個:
# 現在出現的文字{來},共有4個:
# 現在出現的文字{池},共有2個:
# 現在出現的文字{苑},共有1個:
# 現在出現的文字{皆},共有3個:
# 現在出現的文字{依},共有1個:
# 現在出現的文字{舊},共有2個:
# 現在出現的文字{太},共有2個:
# 現在出現的文字{液},共有1個:
# 現在出現的文字{芙},共有3個:
# 現在出現的文字{蓉},共有3個:
# 現在出現的文字{未},共有3個:
# 現在出現的文字{央},共有1個:
# 現在出現的文字{柳},共有2個:
# 現在出現的文字{芙},共有3個:
# 現在出現的文字{蓉},共有3個:
# 現在出現的文字{如},共有4個:
# 現在出現的文字{面},共有2個:
# 現在出現的文字{柳},共有2個:
# 現在出現的文字{如},共有4個:
# 現在出現的文字{眉},共有2個:
# 現在出現的文字{對},共有1個:
# 現在出現的文字{此},共有4個:
# 現在出現的文字{如},共有4個:
# 現在出現的文字{何},共有2個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{淚},共有3個:
# 現在出現的文字{垂},共有1個:
# 現在出現的文字{春},共有8個:
# 現在出現的文字{風},共有4個:
# 現在出現的文字{桃},共有1個:
# 現在出現的文字{李},共有1個:
# 現在出現的文字{花},共有6個:
# 現在出現的文字{開},共有2個:
# 現在出現的文字{日},共有6個:
# 現在出現的文字{秋},共有2個:
# 現在出現的文字{雨},共有3個:
# 現在出現的文字{梧},共有1個:
# 現在出現的文字{桐},共有1個:
# 現在出現的文字{葉},共有2個:
# 現在出現的文字{落},共有3個:
# 現在出現的文字{時},共有4個:
# 現在出現的文字{西},共有4個:
# 現在出現的文字{宮},共有6個:
# 現在出現的文字{南},共有2個:
# 現在出現的文字{內},共有1個:
# 現在出現的文字{多},共有3個:
# 現在出現的文字{秋},共有2個:
# 現在出現的文字{草},共有1個:
# 現在出現的文字{落},共有3個:
# 現在出現的文字{葉},共有2個:
# 現在出現的文字{滿},共有1個:
# 現在出現的文字{階},共有1個:
# 現在出現的文字{紅},共有1個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{掃},共有1個:
# 現在出現的文字{梨},共有2個:
# 現在出現的文字{園},共有1個:
# 現在出現的文字{子},共有3個:
# 現在出現的文字{弟},共有2個:
# 現在出現的文字{白},共有1個:
# 現在出現的文字{髮},共有1個:
# 現在出現的文字{新},共有3個:
# 現在出現的文字{椒},共有1個:
# 現在出現的文字{房},共有1個:
# 現在出現的文字{阿},共有1個:
# 現在出現的文字{監},共有1個:
# 現在出現的文字{青},共有3個:
# 現在出現的文字{娥},共有1個:
# 現在出現的文字{老},共有1個:
# 現在出現的文字{夕},共有1個:
# 現在出現的文字{殿},共有3個:
# 現在出現的文字{螢},共有1個:
# 現在出現的文字{飛},共有1個:
# 現在出現的文字{思},共有3個:
# 現在出現的文字{悄},共有1個:
# 現在出現的文字{然},共有1個:
# 現在出現的文字{孤},共有1個:
# 現在出現的文字{燈},共有1個:
# 現在出現的文字{挑},共有1個:
# 現在出現的文字{盡},共有4個:
# 現在出現的文字{未},共有3個:
# 現在出現的文字{成},共有4個:
# 現在出現的文字{眠},共有1個:
# 現在出現的文字{遲},共有2個:
# 現在出現的文字{遲},共有2個:
# 現在出現的文字{鐘},共有1個:
# 現在出現的文字{鼓},共有2個:
# 現在出現的文字{初},共有2個:
# 現在出現的文字{長},共有6個:
# 現在出現的文字{夜},共有6個:
# 現在出現的文字{耿},共有2個:
# 現在出現的文字{耿},共有2個:
# 現在出現的文字{星},共有1個:
# 現在出現的文字{河},共有1個:
# 現在出現的文字{欲},共有1個:
# 現在出現的文字{曙},共有1個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{鴛},共有1個:
# 現在出現的文字{鴦},共有1個:
# 現在出現的文字{瓦},共有1個:
# 現在出現的文字{冷},共有1個:
# 現在出現的文字{霜},共有1個:
# 現在出現的文字{華},共有4個:
# 現在出現的文字{重},共有6個:
# 現在出現的文字{翡},共有1個:
# 現在出現的文字{翠},共有3個:
# 現在出現的文字{衾},共有1個:
# 現在出現的文字{寒},共有2個:
# 現在出現的文字{誰},共有1個:
# 現在出現的文字{與},共有1個:
# 現在出現的文字{共},共有1個:
# 現在出現的文字{悠},共有2個:
# 現在出現的文字{悠},共有2個:
# 現在出現的文字{生},共有8個:
# 現在出現的文字{死},共有3個:
# 現在出現的文字{別},共有3個:
# 現在出現的文字{經},共有1個:
# 現在出現的文字{年},共有2個:
# 現在出現的文字{魂},共有3個:
# 現在出現的文字{魄},共有2個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{曾},共有1個:
# 現在出現的文字{來},共有4個:
# 現在出現的文字{入},共有3個:
# 現在出現的文字{夢},共有2個:
# 現在出現的文字{臨},共有2個:
# 現在出現的文字{邛},共有1個:
# 現在出現的文字{道},共有2個:
# 現在出現的文字{士},共有3個:
# 現在出現的文字{鴻},共有1個:
# 現在出現的文字{都},共有3個:
# 現在出現的文字{客},共有1個:
# 現在出現的文字{能},共有2個:
# 現在出現的文字{以},共有1個:
# 現在出現的文字{精},共有1個:
# 現在出現的文字{誠},共有1個:
# 現在出現的文字{致},共有1個:
# 現在出現的文字{魂},共有3個:
# 現在出現的文字{魄},共有2個:
# 現在出現的文字{為},共有2個:
# 現在出現的文字{感},共有1個:
# 現在出現的文字{君},共有7個:
# 現在出現的文字{王},共有6個:
# 現在出現的文字{輾},共有1個:
# 現在出現的文字{轉},共有4個:
# 現在出現的文字{思},共有3個:
# 現在出現的文字{遂},共有2個:
# 現在出現的文字{教},共有3個:
# 現在出現的文字{方},共有1個:
# 現在出現的文字{士},共有3個:
# 現在出現的文字{殷},共有2個:
# 現在出現的文字{勤},共有2個:
# 現在出現的文字{覓},共有1個:
# 現在出現的文字{排},共有1個:
# 現在出現的文字{空},共有2個:
# 現在出現的文字{馭},共有2個:
# 現在出現的文字{氣},共有1個:
# 現在出現的文字{奔},共有1個:
# 現在出現的文字{如},共有4個:
# 現在出現的文字{電},共有1個:
# 現在出現的文字{升},共有1個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{入},共有3個:
# 現在出現的文字{地},共有6個:
# 現在出現的文字{求},共有2個:
# 現在出現的文字{之},共有1個:
# 現在出現的文字{遍},共有1個:
# 現在出現的文字{上},共有3個:
# 現在出現的文字{窮},共有1個:
# 現在出現的文字{碧},共有2個:
# 現在出現的文字{落},共有3個:
# 現在出現的文字{下},共有6個:
# 現在出現的文字{黃},共有3個:
# 現在出現的文字{泉},共有2個:
# 現在出現的文字{兩},共有3個:
# 現在出現的文字{處},共有6個:
# 現在出現的文字{茫},共有3個:
# 現在出現的文字{茫},共有3個:
# 現在出現的文字{皆},共有3個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{見},共有6個:
# 現在出現的文字{忽},共有1個:
# 現在出現的文字{聞},共有4個:
# 現在出現的文字{海},共有1個:
# 現在出現的文字{上},共有3個:
# 現在出現的文字{有},共有5個:
# 現在出現的文字{仙},共有4個:
# 現在出現的文字{山},共有4個:
# 現在出現的文字{山},共有4個:
# 現在出現的文字{在},共有6個:
# 現在出現的文字{虛},共有1個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{縹},共有1個:
# 現在出現的文字{緲},共有1個:
# 現在出現的文字{間},共有2個:
# 現在出現的文字{樓},共有2個:
# 現在出現的文字{閣},共有2個:
# 現在出現的文字{玲},共有1個:
# 現在出現的文字{瓏},共有1個:
# 現在出現的文字{五},共有1個:
# 現在出現的文字{雲},共有5個:
# 現在出現的文字{起},共有4個:
# 現在出現的文字{其},共有1個:
# 現在出現的文字{中},共有5個:
# 現在出現的文字{綽},共有1個:
# 現在出現的文字{約},共有1個:
# 現在出現的文字{多},共有3個:
# 現在出現的文字{仙},共有4個:
# 現在出現的文字{子},共有3個:
# 現在出現的文字{中},共有5個:
# 現在出現的文字{有},共有5個:
# 現在出現的文字{一},共有8個:
# 現在出現的文字{人},共有8個:
# 現在出現的文字{字},共有1個:
# 現在出現的文字{太},共有2個:
# 現在出現的文字{真},共有1個:
# 現在出現的文字{雪},共有1個:
# 現在出現的文字{膚},共有1個:
# 現在出現的文字{花},共有6個:
# 現在出現的文字{貌},共有1個:
# 現在出現的文字{參},共有1個:
# 現在出現的文字{差},共有1個:
# 現在出現的文字{是},共有2個:
# 現在出現的文字{金},共有7個:
# 現在出現的文字{闕},共有2個:
# 現在出現的文字{西},共有4個:
# 現在出現的文字{廂},共有1個:
# 現在出現的文字{叩},共有1個:
# 現在出現的文字{玉},共有6個:
# 現在出現的文字{扃},共有1個:
# 現在出現的文字{轉},共有4個:
# 現在出現的文字{教},共有3個:
# 現在出現的文字{小},共有1個:
# 現在出現的文字{玉},共有6個:
# 現在出現的文字{報},共有1個:
# 現在出現的文字{雙},共有1個:
# 現在出現的文字{成},共有4個:
# 現在出現的文字{聞},共有4個:
# 現在出現的文字{道},共有2個:
# 現在出現的文字{漢},共有2個:
# 現在出現的文字{家},共有2個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{子},共有3個:
# 現在出現的文字{使},共有1個:
# 現在出現的文字{九},共有2個:
# 現在出現的文字{華},共有4個:
# 現在出現的文字{帳},共有2個:
# 現在出現的文字{裡},共有2個:
# 現在出現的文字{夢},共有2個:
# 現在出現的文字{魂},共有3個:
# 現在出現的文字{驚},共有2個:
# 現在出現的文字{攬},共有1個:
# 現在出現的文字{衣},共有4個:
# 現在出現的文字{推},共有1個:
# 現在出現的文字{枕},共有1個:
# 現在出現的文字{起},共有4個:
# 現在出現的文字{徘},共有1個:
# 現在出現的文字{徊},共有1個:
# 現在出現的文字{珠},共有1個:
# 現在出現的文字{箔},共有1個:
# 現在出現的文字{銀},共有1個:
# 現在出現的文字{屏},共有1個:
# 現在出現的文字{迤},共有1個:
# 現在出現的文字{邐},共有1個:
# 現在出現的文字{開},共有2個:
# 現在出現的文字{雲},共有5個:
# 現在出現的文字{鬢},共有2個:
# 現在出現的文字{半},共有2個:
# 現在出現的文字{偏},共有1個:
# 現在出現的文字{新},共有3個:
# 現在出現的文字{睡},共有1個:
# 現在出現的文字{覺},共有1個:
# 現在出現的文字{花},共有6個:
# 現在出現的文字{冠},共有1個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{整},共有1個:
# 現在出現的文字{下},共有6個:
# 現在出現的文字{堂},共有1個:
# 現在出現的文字{來},共有4個:
# 現在出現的文字{風},共有4個:
# 現在出現的文字{吹},共有1個:
# 現在出現的文字{仙},共有4個:
# 現在出現的文字{袂},共有1個:
# 現在出現的文字{飄},共有3個:
# 現在出現的文字{飄},共有3個:
# 現在出現的文字{舉},共有1個:
# 現在出現的文字{猶},共有1個:
# 現在出現的文字{似},共有2個:
# 現在出現的文字{霓},共有2個:
# 現在出現的文字{裳},共有2個:
# 現在出現的文字{羽},共有2個:
# 現在出現的文字{衣},共有4個:
# 現在出現的文字{舞},共有2個:
# 現在出現的文字{玉},共有6個:
# 現在出現的文字{容},共有2個:
# 現在出現的文字{寂},共有1個:
# 現在出現的文字{寞},共有1個:
# 現在出現的文字{淚},共有3個:
# 現在出現的文字{闌},共有1個:
# 現在出現的文字{干},共有1個:
# 現在出現的文字{梨},共有2個:
# 現在出現的文字{花},共有6個:
# 現在出現的文字{一},共有8個:
# 現在出現的文字{枝},共有2個:
# 現在出現的文字{春},共有8個:
# 現在出現的文字{帶},共有1個:
# 現在出現的文字{雨},共有3個:
# 現在出現的文字{含},共有1個:
# 現在出現的文字{情},共有3個:
# 現在出現的文字{凝},共有3個:
# 現在出現的文字{睇},共有1個:
# 現在出現的文字{謝},共有1個:
# 現在出現的文字{君},共有7個:
# 現在出現的文字{王},共有6個:
# 現在出現的文字{一},共有8個:
# 現在出現的文字{別},共有3個:
# 現在出現的文字{音},共有1個:
# 現在出現的文字{容},共有2個:
# 現在出現的文字{兩},共有3個:
# 現在出現的文字{渺},共有1個:
# 現在出現的文字{茫},共有3個:
# 現在出現的文字{昭},共有1個:
# 現在出現的文字{陽},共有2個:
# 現在出現的文字{殿},共有3個:
# 現在出現的文字{裡},共有2個:
# 現在出現的文字{恩},共有2個:
# 現在出現的文字{愛},共有2個:
# 現在出現的文字{絕},共有2個:
# 現在出現的文字{蓬},共有1個:
# 現在出現的文字{萊},共有1個:
# 現在出現的文字{宮},共有6個:
# 現在出現的文字{中},共有5個:
# 現在出現的文字{日},共有6個:
# 現在出現的文字{月},共有3個:
# 現在出現的文字{長},共有6個:
# 現在出現的文字{回},共有3個:
# 現在出現的文字{頭},共有2個:
# 現在出現的文字{下},共有6個:
# 現在出現的文字{望},共有2個:
# 現在出現的文字{人},共有8個:
# 現在出現的文字{寰},共有1個:
# 現在出現的文字{處},共有6個:
# 現在出現的文字{不},共有14個:
# 現在出現的文字{見},共有6個:
# 現在出現的文字{長},共有6個:
# 現在出現的文字{安},共有1個:
# 現在出現的文字{見},共有6個:
# 現在出現的文字{塵},共有2個:
# 現在出現的文字{霧},共有1個:
# 現在出現的文字{唯},共有1個:
# 現在出現的文字{將},共有2個:
# 現在出現的文字{舊},共有2個:
# 現在出現的文字{物},共有1個:
# 現在出現的文字{表},共有1個:
# 現在出現的文字{深},共有2個:
# 現在出現的文字{情},共有3個:
# 現在出現的文字{鈿},共有4個:
# 現在出現的文字{合},共有3個:
# 現在出現的文字{金},共有7個:
# 現在出現的文字{釵},共有3個:
# 現在出現的文字{寄},共有2個:
# 現在出現的文字{將},共有2個:
# 現在出現的文字{去},共有2個:
# 現在出現的文字{釵},共有3個:
# 現在出現的文字{留},共有1個:
# 現在出現的文字{一},共有8個:
# 現在出現的文字{股},共有1個:
# 現在出現的文字{合},共有3個:
# 現在出現的文字{一},共有8個:
# 現在出現的文字{扇},共有1個:
# 現在出現的文字{釵},共有3個:
# 現在出現的文字{擘},共有1個:
# 現在出現的文字{黃},共有3個:
# 現在出現的文字{金},共有7個:
# 現在出現的文字{合},共有3個:
# 現在出現的文字{分},共有1個:
# 現在出現的文字{鈿},共有4個:
# 現在出現的文字{但},共有1個:
# 現在出現的文字{教},共有3個:
# 現在出現的文字{心},共有4個:
# 現在出現的文字{似},共有2個:
# 現在出現的文字{金},共有7個:
# 現在出現的文字{鈿},共有4個:
# 現在出現的文字{堅},共有1個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{上},共有3個:
# 現在出現的文字{人},共有8個:
# 現在出現的文字{間},共有2個:
# 現在出現的文字{會},共有1個:
# 現在出現的文字{相},共有3個:
# 現在出現的文字{見},共有6個:
# 現在出現的文字{臨},共有2個:
# 現在出現的文字{別},共有3個:
# 現在出現的文字{殷},共有2個:
# 現在出現的文字{勤},共有2個:
# 現在出現的文字{重},共有6個:
# 現在出現的文字{寄},共有2個:
# 現在出現的文字{詞},共有2個:
# 現在出現的文字{詞},共有2個:
# 現在出現的文字{中},共有5個:
# 現在出現的文字{有},共有5個:
# 現在出現的文字{誓},共有1個:
# 現在出現的文字{兩},共有3個:
# 現在出現的文字{心},共有4個:
# 現在出現的文字{知},共有1個:
# 現在出現的文字{七},共有2個:
# 現在出現的文字{月},共有3個:
# 現在出現的文字{七},共有2個:
# 現在出現的文字{日},共有6個:
# 現在出現的文字{長},共有6個:
# 現在出現的文字{生},共有8個:
# 現在出現的文字{殿},共有3個:
# 現在出現的文字{夜},共有6個:
# 現在出現的文字{半},共有2個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{人},共有8個:
# 現在出現的文字{私},共有1個:
# 現在出現的文字{語},共有1個:
# 現在出現的文字{時},共有4個:
# 現在出現的文字{在},共有6個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{願},共有2個:
# 現在出現的文字{作},共有1個:
# 現在出現的文字{比},共有1個:
# 現在出現的文字{翼},共有1個:
# 現在出現的文字{鳥},共有1個:
# 現在出現的文字{在},共有6個:
# 現在出現的文字{地},共有6個:
# 現在出現的文字{願},共有2個:
# 現在出現的文字{為},共有2個:
# 現在出現的文字{連},共有1個:
# 現在出現的文字{理},共有1個:
# 現在出現的文字{枝},共有2個:
# 現在出現的文字{天},共有9個:
# 現在出現的文字{長},共有6個:
# 現在出現的文字{地},共有6個:
# 現在出現的文字{久},共有1個:
# 現在出現的文字{有},共有5個:
# 現在出現的文字{時},共有4個:
# 現在出現的文字{盡},共有4個:
# 現在出現的文字{此},共有4個:
# 現在出現的文字{恨},共有1個:
# 現在出現的文字{綿},共有2個:
# 現在出現的文字{綿},共有2個:
# 現在出現的文字{無},共有9個:
# 現在出現的文字{絕},共有2個:
# 現在出現的文字{期},共有1個:
# 出現最多次數的文字是 {不},總共有14個:

# %% [markdown]
# ### 05 - Email 域名判斷器（Email slicer）
# #### 請用戶輸入 Email 地址，然後判斷它是自定義域名還是熱門域名。
#
# > 題目：<br>
# 輸入(Input):shelly200318@hotmail.com.tw  <br>
# 輸出(Output):Your username is 'shelly200318' and your domain name is 'hotmail.com.tw' <br>
#
#
# * 進階：把常用的信箱存成字典，加入判斷是否為
# >輸入(Input):mary.jane@gmail.com  <br>
# 輸出(Output):這是註冊在 Google 之下的 Email 地址 <br>
# 輸入(Input):matt.pan@myfantasy.com  <br>
# 輸出(Output):這是在 myfantasy 之下自定義域

# %%
# Get user email address
email = input("What is your email address?: ").strip()

user_name=email[0:email.index('@')]
domain_name=email[email.index('@'):]

output = "Your username is '{}' and your domain name is '{}'".format(user_name,domain_name)

# Display output message
print(output)


domain = {'gmail.com':'Google','yahoo.com.tw':'Yahoo','ntu.edu.tw':'臺大','hotmail.com.tw':'Hotmail','hotmail.com':'Hotmail'}
if domain_name in domain:
    output = "這是註冊在 {} 之下的 Email 地址'".format(domain[domain_name])
else:
    output = "這是在 {} 之下自定義域".format(domain_name)
print(output)
# Out:
# What is your email address?: mary.jane@gmil.com
# Your username is 'mary.jane' and your domain name is '@gmil.com'
# 這是在 @gmil.com 之下自定義域

# %% [markdown]
# ### 06 - 及格名單（Pass list）
# #### 請使用集合功能來完成各科級名單的判斷
# ```
# 米花市帝丹小學一年级B班正舉辦期中考試
# 數學及格的有：柯南、灰原、步美、美環、光彦
# 英文及格的有：柯南、灰原、丸尾、野口、步美
# 以上已列出全班所有人
# ```
#
# >請分別列出<br>
# 數學及格但英文不及格的同學名單<br>
# 數學不及格但英文及格的同學名單<br>
# 兩者皆及格名單<br>
# * Hint:差集(減法)、交集

# %%
m={'柯南','灰原','步美','美環','光彦'}
e={'柯南','灰原','丸尾','野口','步美'}
a=m.intersection(e)
b=m.difference(a)
c=e.difference(a)
a1=list(a)
b1=list(b)
c1=list(c)
b1.sort
c1.sort
a1.sort
print(b1)
print(c1)
print(a1)
# Out:
# ['光彦', '美環']
# ['丸尾', '野口']
# ['灰原', '步美', '柯南']

# %% [markdown]
# ### 07 - 查詢路徑下所有檔案
# #### 請使用者輸入路徑，自動抓取路徑下所有檔案名稱
#
# >輸入(Input):data\testfile 或 D:\code\ML_202105\data\testfile  <br>
# 輸出(Output):
# ```
# I'm a directory: file1
# I'm a directory: file2
# I'm a File: hw_07945001.txt
# I'm a File: hw_079450010.doc
# I'm a File: hw_07945002.txt
# I'm a File: hw_07945003.txt
# I'm a File: hw_07945004.txt
# I'm a File: hw_07945005.txt
# I'm a File: hw_07945007.txt
# I'm a File: hw_07945008.txt
# I'm a File: hw_07945009.txt
# ```
#
# * 進階: 把file的學號抓出來，另存成一個新的csv檔

# %%
import os
yourPath = input()
allFileList = os.listdir(yourPath)
ID=[]
for file in allFileList:
    if os.path.isdir(os.path.join(yourPath,file)):
        print("I'm a directory: " + file)
    elif os.path.isfile(os.path.join(yourPath,file)):
        print("I'm a File: " + file)
        ID.append(file[file.index('_')+1:file.index('.')])
print(ID)
# Out:
# testfile
# I'm a directory: file1
# I'm a directory: file2
# I'm a File: hw_07945001.txt
# I'm a File: hw_079450010.doc
# I'm a File: hw_07945002.txt
# I'm a File: hw_07945003.txt
# I'm a File: hw_07945004.txt
# I'm a File: hw_07945005.txt
# I'm a File: hw_07945007.txt
# I'm a File: hw_07945008.txt
# I'm a File: hw_07945009.txt
# ['07945001', '079450010', '07945002', '07945003', '07945004', '07945005', '07945007', '07945008', '07945009']

# %% [markdown]
# ### 08 - 資料夾管理(shutil)
# #### 說明 ####
#
# ```
# 在目前所在的目錄下建立一files資料夾
#
# 令使用者輸入一數字N，並在files資料夾中建立f1, f2… fN等N個資料夾後列出files的資料夾內容
#
# 將files資料夾裡的f1資料夾重新命名成folder1後再列出files的資料夾內容
#
# 移除files資料夾中的folder1後再列出files的資料夾內容
#
# 最後移除files資料夾
# ※須先退出files資料夾(os.chdir(../)) ![image.png](attachment:image.png)
# ```

# %%
import os
import shutil

# 建立的目錄路徑
#folderpath =input()

# 使用 try 建立目錄
#try:
 #   os.mkdir(folderpath)
# 檔案已存在的例外處理
#except FileExistsError:
 #       shutil.rmtree(folderpath)
  #      a=input('Enter')
   #     os.mkdir(folderpath)
        
#a=input('Enter')

if os.path.exists('files'):
      shutil.rmtree('files')
os.mkdir('files')

n = int(input())
os.chdir('files')
for i in range(1,n+1):
    os.mkdir('f'+str(i))
print(sorted(os.listdir()))
a=input('Enter')

os.rename('f1','folder1')
print(sorted(os.listdir()))
a=input('Enter')

os.rmdir('folder1')
print(sorted(os.listdir()))
a=input('Enter')

os.chdir('../')
shutil.rmtree('files')
# Out:
# 8
# ['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8']
# Enter
# ['f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'folder1']
# Enter
# ['f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8']
# Enter

# %% [markdown]
# ### 09 - 回文判斷（Is a palindrome）
# #### 請使用者輸入單字，判斷它是否為回文，也就是該單字前後對稱，例如 madam，從前讀到後或是從後讀到前的順序都是 madam。
#
# > 題目：<br>
# 輸入(Input): 雨 滋 春 樹 碧 連 天  天 連 碧 樹 春 滋 雨 <br>
# 輸出(Output):The text you have entered is a palindrome!<br>
# 輸入(Input): 資工訓練班 <br>
# 輸出(Output):The text you have entered is not a palindrome.

# %%
def convertInputString():
    #請使用者輸入一串字串，先轉換字串為統一小寫
    rawInput = input("\nPlease enter a word, phrase, or a sentence \nto check if it is a palindrome: ") 
    rawString=rawInput.lower()
    rawList=list(rawString)
    print(rawList)
    return rawList

def stripAnalphabetics(dirtyList): 
    analphabeticList = [" ", "-", ".", ",", ":", ";", "!", "?", "'", "\""] 
    for character in analphabeticList:
        if character in dirtyList:
            dirtyList.remove(character)
            return stripAnalphabetics(dirtyList)
    return dirtyList

def runPalindromeCheck(straightList):
    reversedList = straightList[::-1] 
    if reversedList==straightList:
        return "The text you have entered is a palindrome!" 
    else: 
        return "The text you have entered is not a palindrome." 

def main(): 
    print("\nPalindrome checker") 
    originalList=convertInputString()
    originalList=stripAnalphabetics(originalList)
    PalindromeCheck=runPalindromeCheck(originalList)
    print(PalindromeCheck)
  
main()
# Out:
# Palindrome checker
#
# Please enter a word, phrase, or a sentence
# to check if it is a palindrome: abcdefg......======!!!!!!???????.......gfedcba
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', '.', '.', '.', '.', '.', '.', '=', '=', '=', '=', '=', '=', '!', '!', '!', '!', '!', '!', '?', '?', '?', '?', '?', '?', '?', '.', '.', '.', '.', '.', '.', '.', 'g', 'f', 'e', 'd', 'c', 'b', 'a']
# The text you have entered is a palindrome!

# %% [markdown]
# ### 10 - 總成績計算
# #### 說明 ####
#
# 請讀取 `data/english_list.csv`與`data/math_list.csv`檔案(`utf-8`)後，將每位同學的英文與數學成績加總起來，並將檔案寫入至 `./Score.csv`中，編碼成`utf-8`<br>
# 最後列印出每位學生姓名與加總後的分數<br>
# <a href="data\english_list.csv">英文成績下載</a><br>
# <a href="data\math_list.csv">數學成績下載</a><br>
#
# #### Input Format ####
#
# <br>
# csv資料(英文成績)<br>
# csv資料(數學成績)<br>
# <br>
#
# #### Output Format ####
#
# <br>
#
# ![](data\05.JPG)<br>
# <br>
# <br>
# (圖片參考用 以文字敘述為準)<br>
#
#
#
#
# #### Sample Input 1####
#
#
#
# ```
# 無標準輸入，只有檔案輸入
# ```
#
#
#
# #### Sample Output 1####
#
#
# ```
# 廖冠霖 142
# 王力中 124
# 張平舜 108
# .
# .
# .
# .
# .
# 陳姿茜 77
# 涂珮瑜 134
# 夏明哲 111
#
# ```
#
#
# #### Hint ####
#
#
#
# ```
# None
# ```

# %%
fin_E = open("data/english_list.csv","r",encoding='UTF-8')
fin_M = open("data/math_list.csv","r",encoding='UTF-8')
lisE=[]
lisM=[]
name=[]
for line in fin_E.readlines():
    line = line.strip().split(",")
    name.append(line[0])
    lisE.append(line[1])
    
for line in fin_M.readlines():
    line = line.strip().split(",")
    lisM.append(line[1])

score=[]
fout = open("Score.csv","w")
line=''
for i in range(1,len(name)):
    score.append(int(lisE[i])+int(lisM[i]))
    list1 = [name[i],str(score[i-1]),"\n"]
    print(name[i],str(score[i-1]))
    
    line = ",".join(list1)
    fout.write(line)
fin_E.close()
fin_M.close()
fout.close()

'''
line=''

fout = open("Score.csv","r")
  print()
'''
# Out:
# 廖冠霖 142
# 王力中 124
# 張平舜 108
# 洪婷婷 128
# 林士雨 86
# 陳宗翰 28
# 洪偉珊 134
# 顏又芹 32
# 王亦夏 55
# 姚成華 77
# 潘詠月 144
# 倪浩迪 163
# 郭心怡 109
# 黃政聖 99
# 顏曉雲 135
# 彭曉雯 77
# 葉健仁 117
# 賴軒年 167
# 韓致遠 52
# 陳常芝 80
# 黃佩樺 108
# 林詩虹 178
# 黃心卿 96
# 郭奕全 101
# 游子揚 127
# 杜茜行 107
# 李美一 64
# 陳姿茜 77
# 涂珮瑜 134
# 夏明哲 111
# '\nline=\'\'\n\nfout = open("Score.csv","r")\n  print()\n'
